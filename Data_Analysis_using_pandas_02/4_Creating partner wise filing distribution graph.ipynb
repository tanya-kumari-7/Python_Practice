# %% [markdown]
# ## IMPORTS

# %%
# IMPORTS
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## Reading CSV

# %%
offline_df = pd.read_csv(r"C:\Users\user\Downloads\offline_paid.csv")
offline_df.head(5)
# Out:
#    emitra_id   itr_id sp_name  sso_id sp_transaction_id        csc_id  \
# 0     665705  2059165  sp_csc  929814               NaN  4.775241e+11
# 1     646264  2030728  sp_csc  387502               NaN  2.444665e+11
# 2     707061  2144797  sp_csc  138501               NaN  2.558573e+11
# 3     691888  2109081  sp_csc  225636               NaN  7.266127e+11
# 4     730799  2197259  sp_csc   87234               NaN  5.334647e+11
#
#     merchant_id           merchant_name               merchant_email  \
# 0  477524120010            477524120010          dk3090147@gmail.com
# 1  244466540014  Ranjeet Kumar Kushwaha   kushwahamobile97@gmail.com
# 2  255857270010           Jahirul Islam  jahirulislam.1116@gmail.com
# 3  726612670019    Pravin Ramdas Gunjal       Filingo.Pune@gmail.com
# 4  533464730012     Nirmal Kumar Sharma    nirmalsharma769@gmail.com
#
#    merchant_phone  ...     Ops_category2_status  Ops_category3_status  \
# 0    9.451269e+09  ...          wrong password                    NaN
# 1    9.771090e+09  ...             TO BE CLOSED                   NaN
# 2    8.638447e+09  ...  194LA Documents pending                    p1
# 3    7.710097e+09  ...        Details Pending                     NaN
# 4    9.431310e+09  ...                     hold                   NaN
#
#   team_reamrks_count   User_type   Vle_type   Income_band     FY_Year  \
# 0                6.0  Retro_User    New_Vle  G).No_Income  FY 2024-25
# 1                5.0    New_User  Retro_Vle  G).No_Income  FY 2024-25
# 2                7.0    New_User  Retro_Vle  G).No_Income  FY 2024-25
# 3                7.0    New_User    New_Vle  G).No_Income  FY 2024-25
# 4                3.0  Retro_User  Retro_Vle  G).No_Income  FY 2024-25
#
#   Days_E_verification Days_E_verification_done  \
# 0                 NaN                      NaN
# 1                 NaN                      NaN
# 2                 NaN                      NaN
# 3                 NaN                      NaN
# 4                 NaN                      NaN
#
#              E_verification_bucket
# 0  F)Pending for more than 30 days
# 1  F)Pending for more than 30 days
# 2  F)Pending for more than 30 days
# 3  F)Pending for more than 30 days
# 4  F)Pending for more than 30 days
#
# [5 rows x 105 columns]

# %% [markdown]
# ## EXPLORE DATA

# %%
pd.set_option('display.max_columns', None)

# %%
offline_df.head(5)
# Out:
#    emitra_id   itr_id sp_name  sso_id sp_transaction_id        csc_id  \
# 0     665705  2059165  sp_csc  929814               NaN  4.775241e+11
# 1     646264  2030728  sp_csc  387502               NaN  2.444665e+11
# 2     707061  2144797  sp_csc  138501               NaN  2.558573e+11
# 3     691888  2109081  sp_csc  225636               NaN  7.266127e+11
# 4     730799  2197259  sp_csc   87234               NaN  5.334647e+11
#
#     merchant_id           merchant_name               merchant_email  \
# 0  477524120010            477524120010          dk3090147@gmail.com
# 1  244466540014  Ranjeet Kumar Kushwaha   kushwahamobile97@gmail.com
# 2  255857270010           Jahirul Islam  jahirulislam.1116@gmail.com
# 3  726612670019    Pravin Ramdas Gunjal       Filingo.Pune@gmail.com
# 4  533464730012     Nirmal Kumar Sharma    nirmalsharma769@gmail.com
#
#    merchant_phone                 pi_vle_email  pi_vle_phone  \
# 0    9.451269e+09          dk3090147@gmail.com  9.451269e+09
# 1    9.771090e+09   kushwahamobile97@gmail.com  9.771090e+09
# 2    8.638447e+09  jahirulislam.1116@gmail.com  8.638447e+09
# 3    7.710097e+09       Filingo.Pune@gmail.com  7.710097e+09
# 4    9.431310e+09    nirmalsharma769@gmail.com  9.431310e+09
#
#             merchant_vle_email  merchant_vle_phone        Customer_name  \
# 0          dk3090147@gmail.com                 NaN    DINESH CHAURASIYA
# 1   kushwahamobile97@gmail.com                 NaN        DASHRATH SAHU
# 2  jahirulislam.1116@gmail.com                 NaN           DELDAR ALI
# 3            isk1901@gmail.com                 NaN       Akshay Bhosale
# 4    nirmalsharma769@gmail.com                 NaN  NIRMAL KUMAR SHARMA
#
#    Customer_mobile_no               customer_email         pan  \
# 0        9.451269e+09          dk3090147@gmail.com  BHZPC0189D
# 1        8.002309e+09        223surendra@gmail.com  FRLPS0040B
# 2        9.365060e+09       alideldar537@gmail.com  BABPA4978D
# 3        7.798076e+09  AkshayBhosale.420@gmail.com  BXYPB3204P
# 4        9.431310e+09    nirmalsharma769@gmail.com  CFGPS7387H
#
#       Payment_datetime Payment_date user_created cust_first_filing_date  \
# 0  2024-06-14T13:11:58   2024-06-14   2021-11-16             2022-07-28
# 1  2024-05-23T09:29:44   2024-05-23   2024-05-23             2024-05-23
# 2  2024-07-12T08:27:26   2024-07-12   2024-07-12             2024-07-12
# 3  2024-07-02T17:05:35   2024-07-02   2023-01-09             2024-07-02
# 4  2024-07-22T14:11:41   2024-07-22   2019-08-07             2019-08-07
#
#   cust_last_filing_date Merchant_first_filing_date merchant_last_filing_date  \
# 0            2024-06-14                 2024-06-14                2024-06-14
# 1            2024-05-23                 2022-07-23                2024-07-20
# 2            2024-07-12                 2021-08-19                2024-07-23
# 3            2024-07-02                 2024-07-02                2024-07-02
# 4            2024-07-22                 2019-08-07                2024-07-22
#
#   merchant_created_on LSP_Deatils merchant_created_month_year  transactionid  \
# 0          2024-05-08         NaN                     2024-05        5772379
# 1          2021-10-09         NaN                     2021-10        5500189
# 2          2020-07-29         NaN                     2020-07        6351348
# 3          2021-05-30         NaN                     2021-05        6151221
# 4          2019-07-29         NaN                     2019-07        6606787
#
#    transamt  Gross_revenue  Net_Revenue  Net_Revenue_with_gst  \
# 0    1770.0    1500.000000   750.000000                 885.0
# 1     399.0     338.135593   169.067797                 199.5
# 2     399.0     338.135593   169.067797                 199.5
# 3     642.0     544.067797   272.033898                 321.0
# 4     642.0     544.067797   272.033898                 321.0
#
#    assessment_year form_name itr_status itr_status_remarks filing_Status  \
# 0             2024     ITR-4   imported                NaN      imported
# 1             2024     ITR-2     closed                NaN        closed
# 2             2024     ITR-2       open                NaN          open
# 3             2024     ITR-4   imported                NaN      imported
# 4             2024     ITR-4   imported                NaN      imported
#
#    ack_no itr_e_verified_on E_verification_status     filing_timestamp  \
# 0     NaN               NaN          Not_verified  2024-06-14T07:42:01
# 1     NaN               NaN          Not_verified  2024-08-20T12:33:05
# 2     NaN               NaN          Not_verified  2024-07-16T09:44:33
# 3     NaN               NaN          Not_verified  2024-07-02T11:35:36
# 4     NaN               NaN          Not_verified  2024-07-22T08:41:46
#
#                                   deductor_name_base     deductor_name  \
# 0                              RNFI SERVICES LIMITED  tds_not_deducted
# 1  CENTRAL COALFIELDS LIMITED AMARPALI   CHANDRAG...  tds_not_deducted
# 2               DEPUTY COMMISSIONER LAND ACQUISITION  tds_not_deducted
# 3                                                NaN  tds_not_deducted
# 4                                                NaN  tds_not_deducted
#
#   delegate_status      Filing_type Filing_mode Plan_amt_range plan  plan_mrp  \
# 0             NaN  customer_filing         NaN        e >1000  NaN       NaN
# 1             NaN  customer_filing         NaN      c 300-500  NaN       NaN
# 2             NaN  customer_filing         NaN      c 300-500  NaN       NaN
# 3             NaN  customer_filing         NaN     d 500-1000  NaN       NaN
# 4             NaN       VLE Filing         NaN     d 500-1000  NaN       NaN
#
#    plan_offer  plan_rate  plan_mrp_without_discount  plan_commission  \
# 0         NaN        NaN                        NaN              NaN
# 1         NaN        NaN                        NaN              NaN
# 2         NaN        NaN                        NaN              NaN
# 3         NaN        NaN                        NaN              NaN
# 4         NaN        NaN                        NaN              NaN
#
#           Age_bucket gender Latest_Salaried_income Latest_Business_income  \
# 0  between 25 and 40    NaN                     No                     No
# 1  between 41 and 60      M                     No                     No
# 2  between 41 and 60      M                     No                     No
# 3  between 25 and 40    NaN                     No                     No
# 4  between 41 and 60    NaN                     No                     No
#
#   Latest_os_income Latest_hp_income Latest_Business_income_band  \
# 0               No               No                         a)0
# 1               No               No                         a)0
# 2               No               No                         a)0
# 3               No               No                         a)0
# 4               No               No                         a)0
#
#   Latest_Salaried_income_band Latest_os_income_band Latest_hp_income_band  \
# 0                         a)0                   a)0                   a)0
# 1                         a)0                   a)0                   a)0
# 2                         a)0                   a)0                   a)0
# 3                         a)0                   a)0                   a)0
# 4                         a)0                   a)0                   a)0
#
#   Latest_capital_gain_band Gross_total_income_band            income_by_form  \
# 0                      a)0                     a)0                no_details
# 1                      a)0                     a)0                no_details
# 2                      a)0                     a)0                no_details
# 3                      a)0                     a)0                no_details
# 4                      a)0                     a)0  gross_total_income_<2.5L
#
#   total_income_band tds_refund_band Tax_payable_slabs  Tax_deducted  \
# 0               a)0           a).₹0            No_tax           NaN
# 1               a)0           a).₹0            No_tax           NaN
# 2               a)0           a).₹0            No_tax           NaN
# 3               a)0           a).₹0            No_tax           NaN
# 4               a)0           a).₹0            No_tax           NaN
#
#   tax_deducted_band Form_16_upload Tax_liable EightyC Eightyd Eightyccd1b  \
# 0             a).₹0             No         No     NaN      No          No
# 1             a).₹0             No         No     NaN      No          No
# 2             a).₹0             No         No     NaN      No          No
# 3             a).₹0             No         No     NaN      No          No
# 4             a).₹0             No         No     NaN      No          No
#
#     pincode        state        district    Tier T_B_30_status   zone  \
# 0  272206.0        Delhi  SIDDHARTHNAGAR  Tier 3          B_30  NORTH
# 1  825321.0    Jharkhand          Chatra  Tier 3          B_30   EAST
# 2  783334.0        Assam          Dhubri  Tier 3          B_30   EAST
# 3  415109.0  Maharashtra            Pune  Tier 3          B_30   WEST
# 4  814101.0    Jharkhand           Dumka  Tier 3          B_30   EAST
#
#    itr_filed_in_campaign_period_2021  itr_filed_in_campaign_period_2022  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
#
#    itr_filed_in_campaign_period_2023  itr_filed_in_campaign_period_2024  \
# 0                                NaN                                1.0
# 1                                9.0                               19.0
# 2                                2.0                               59.0
# 3                                NaN                                2.0
# 4                                2.0                                1.0
#
#              contest_status json_mode    _26as_imported_on  \
# 0                       NaN       NaN  2024-06-14T13:13:16
# 1  contest_winner_only_2023       NaN  2024-06-26T17:56:44
# 2  contest_winner_only_2023       NaN  2024-07-16T15:12:12
# 3                       NaN       NaN                  NaN
# 4  contest_winner_only_2023       NaN                  NaN
#
#   _26as_import_status ais_status         details_added_by GSTR_Status  \
# 0      _26as_imported        NaN  income_detail_by_client         NaN
# 1      _26as_imported        ais  income_detail_by_client         NaN
# 2      _26as_imported        ais     income_detail_by_VLE         NaN
# 3                 NaN        NaN  income_detail_by_client         NaN
# 4                 NaN        NaN  income_detail_by_client         NaN
#
#   Ops_category1_status     Ops_category2_status Ops_category3_status  \
# 0                  NaN          wrong password                   NaN
# 1         TO BE CLOSED             TO BE CLOSED                  NaN
# 2                  NaN  194LA Documents pending                   p1
# 3                  NaN        Details Pending                    NaN
# 4                  NaN                     hold                  NaN
#
#    team_reamrks_count   User_type   Vle_type   Income_band     FY_Year  \
# 0                 6.0  Retro_User    New_Vle  G).No_Income  FY 2024-25
# 1                 5.0    New_User  Retro_Vle  G).No_Income  FY 2024-25
# 2                 7.0    New_User  Retro_Vle  G).No_Income  FY 2024-25
# 3                 7.0    New_User    New_Vle  G).No_Income  FY 2024-25
# 4                 3.0  Retro_User  Retro_Vle  G).No_Income  FY 2024-25
#
#    Days_E_verification  Days_E_verification_done  \
# 0                  NaN                       NaN
# 1                  NaN                       NaN
# 2                  NaN                       NaN
# 3                  NaN                       NaN
# 4                  NaN                       NaN
#
#              E_verification_bucket
# 0  F)Pending for more than 30 days
# 1  F)Pending for more than 30 days
# 2  F)Pending for more than 30 days
# 3  F)Pending for more than 30 days
# 4  F)Pending for more than 30 days

# %%
offline_df.tail(5)
# Out:
#       emitra_id   itr_id sp_name  sso_id sp_transaction_id        csc_id  \
# 7894     630653  2009758  sp_csc   97343  4114092522902276  3.717526e+11
# 7895     825625  2354005  sp_csc  103069  5006181523708235  1.536522e+11
# 7896     831661  2361797  sp_csc  792580  5026093426602997  6.442722e+11
# 7897     758455  2248209  sp_csc  295495  4210211426071585  3.382154e+11
# 7898     792448  2311320  sp_csc  800216  4245213223697652  6.577128e+11
#
#        merchant_id       merchant_name             merchant_email  \
# 7894  371752560015   Kisan Dilip Deore          deorekd@gmail.com
# 7895  153652160017  Rahul Kumar Maurya      rkm05061994@gmail.com
# 7896  644272160012               Arjun       arjunsbl98@gmail.com
# 7897  338215400017        Sudesh Nayak     sudeshamgcsc@gmail.com
# 7898  657712760012        657712760012  suyashsachan774@gmail.com
#
#       merchant_phone               pi_vle_email  pi_vle_phone  \
# 7894    9.689052e+09          deorekd@gmail.com  9.689052e+09
# 7895    8.795855e+09      rkm05061994@gmail.com  8.795855e+09
# 7896    8.791300e+09       arjunsbl98@gmail.com  8.791300e+09
# 7897    9.424947e+09     sudeshamgcsc@gmail.com  9.424947e+09
# 7898    6.261968e+09  suyashsachan774@gmail.com  6.261968e+09
#
#              merchant_vle_email  merchant_vle_phone   Customer_name  \
# 7894          deorekd@gmail.com                 NaN  YOGESH VISPUTE
# 7895      rkm05061994@gmail.com                 NaN   SHIVAM SHUKLA
# 7896       arjunsbl98@gmail.com                 NaN          KAVITA
# 7897     sudeshamgcsc@gmail.com                 NaN    RAJESH GUPTA
# 7898  suyashsachan774@gmail.com                 NaN     AWADH UTTAM
#
#       Customer_mobile_no                  customer_email         pan  \
# 7894        7.972742e+09       yogeshvispute23@gmail.com  BEOPV3697H
# 7895        8.052057e+09       SHUKLASHIVAM061@GMAIL.COM  AEDPZ3420N
# 7896        7.055771e+09     arjunsainisaini98@gmail.com  NQNPK1437H
# 7897        9.425169e+09      rajeshguptaamg01@gmail.com  AVXPG1984F
# 7898        8.528897e+09  independentonlinehub@gmail.com  ABJPU3496J
#
#          Payment_datetime Payment_date user_created cust_first_filing_date  \
# 7894  2024-04-23T09:25:41   2024-04-23   2024-04-22             2024-04-23
# 7895  2025-01-06T18:16:24   2025-01-06   2025-01-06             2025-01-06
# 7896  2025-01-26T09:34:50   2025-01-26   2025-01-26             2025-01-26
# 7897  2024-07-28T21:14:53   2024-07-28   2024-07-28             2024-07-28
# 7898  2024-09-01T21:33:01   2024-09-01   2024-09-01             2024-09-01
#
#      cust_last_filing_date Merchant_first_filing_date  \
# 7894            2024-04-23                 2019-09-16
# 7895            2025-01-06                 2022-07-30
# 7896            2025-01-26                 2024-08-10
# 7897            2024-07-28                 2024-07-27
# 7898            2024-09-01                 2024-09-01
#
#      merchant_last_filing_date merchant_created_on LSP_Deatils  \
# 7894                2024-07-28          2019-09-16         NaN
# 7895                2025-01-06          2019-11-03         NaN
# 7896                2025-02-08          2023-07-15         NaN
# 7897                2024-07-28          2021-07-30         NaN
# 7898                2024-09-01          2023-07-24         NaN
#
#      merchant_created_month_year  transactionid  transamt  Gross_revenue  \
# 7894                     2019-09        5282547     642.0     544.067797
# 7895                     2019-11        8096758     642.0     544.067797
# 7896                     2023-07        8211129     642.0     544.067797
# 7897                     2021-07        6868353     642.0     544.067797
# 7898                     2023-07        7281260     642.0     544.067797
#
#       Net_Revenue  Net_Revenue_with_gst  assessment_year form_name  \
# 7894   272.033898                 321.0             2023     ITR-4
# 7895   272.033898                 321.0             2024     ITR-4
# 7896   272.033898                 321.0             2025     ITR-4
# 7897   272.033898                 321.0             2024     ITR-4
# 7898   272.033898                 321.0             2024     ITR-2
#
#       itr_status itr_status_remarks filing_Status        ack_no  \
# 7894    imported                NaN      imported           NaN
# 7895  e-verified                NaN     itr_filed  8.076574e+14
# 7896    imported                NaN      imported           NaN
# 7897  e-verified                NaN     itr_filed  1.775552e+14
# 7898  e-verified                NaN     itr_filed  4.249291e+14
#
#      itr_e_verified_on E_verification_status     filing_timestamp  \
# 7894               NaN          Not_verified  2024-04-23T03:55:41
# 7895        2025-01-07              verified  2025-01-07T14:44:17
# 7896               NaN          Not_verified  2025-01-26T04:04:51
# 7897        2024-07-30              verified  2024-07-29T15:13:13
# 7898        2024-09-05              verified  2024-09-05T12:23:12
#
#                        deductor_name_base     deductor_name delegate_status  \
# 7894                                  NaN  tds_not_deducted             NaN
# 7895                 BAAZI NETWORKS P LTD  tds_not_deducted             NaN
# 7896                                  NaN  tds_not_deducted             NaN
# 7897  ATYATI TECHNOLOGIES PRIVATE LIMITED  tds_not_deducted             NaN
# 7898                                  NaN  tds_not_deducted             NaN
#
#           Filing_type             Filing_mode Plan_amt_range  \
# 7894  customer_filing                     NaN     d 500-1000
# 7895  customer_filing  Filing_through_website     d 500-1000
# 7896  customer_filing                     NaN     d 500-1000
# 7897  customer_filing  Filing_through_website     d 500-1000
# 7898  customer_filing  Filing_through_website     d 500-1000
#
#                                   plan  plan_mrp  plan_offer  plan_rate  \
# 7894      business_income_less_than_20     642.0         0.0      321.0
# 7895  vle_business_income_less_than_20     642.0         0.0      321.0
# 7896      business_income_less_than_20     642.0         0.0      321.0
# 7897  vle_business_income_less_than_20     642.0         0.0      321.0
# 7898      business_income_less_than_20     642.0         0.0      321.0
#
#       plan_mrp_without_discount  plan_commission         Age_bucket gender  \
# 7894                      642.0            321.0  between 25 and 40      M
# 7895                      642.0            321.0  between 25 and 40      M
# 7896                      642.0            321.0  between 25 and 40    NaN
# 7897                      642.0            321.0  between 25 and 40    NaN
# 7898                      642.0            321.0  between 41 and 60      M
#
#      Latest_Salaried_income Latest_Business_income Latest_os_income  \
# 7894                     No                     No               No
# 7895                     No                     No               No
# 7896                     No                     No               No
# 7897                     No                     No               No
# 7898                     No                     No               No
#
#      Latest_hp_income Latest_Business_income_band Latest_Salaried_income_band  \
# 7894               No                         a)0                         a)0
# 7895               No                         a)0                         a)0
# 7896               No                         a)0                         a)0
# 7897               No                         a)0                         a)0
# 7898               No                         a)0                         a)0
#
#      Latest_os_income_band Latest_hp_income_band Latest_capital_gain_band  \
# 7894                   a)0                   a)0                      a)0
# 7895                   a)0                   a)0                      a)0
# 7896                   a)0                   a)0                      a)0
# 7897                   a)0                   a)0                      a)0
# 7898                   a)0                   a)0                      a)0
#
#      Gross_total_income_band            income_by_form total_income_band  \
# 7894                     a)0  gross_total_income_>2.5L               a)0
# 7895                     a)0  gross_total_income_<2.5L               a)0
# 7896                     a)0                no_details               a)0
# 7897                     a)0                no_details               a)0
# 7898                     a)0  gross_total_income_<2.5L               a)0
#
#      tds_refund_band Tax_payable_slabs  Tax_deducted tax_deducted_band  \
# 7894           a).₹0            No_tax           NaN             a).₹0
# 7895           a).₹0            No_tax           NaN             a).₹0
# 7896           a).₹0            No_tax           NaN             a).₹0
# 7897           a).₹0            No_tax           NaN             a).₹0
# 7898           a).₹0            No_tax           NaN             a).₹0
#
#      Form_16_upload Tax_liable EightyC Eightyd Eightyccd1b   pincode  \
# 7894             No         No     NaN      No          No  424307.0
# 7895             No         No     NaN      No          No  229307.0
# 7896             No         No     NaN      No          No  244302.0
# 7897             No         No     NaN      No          No  487225.0
# 7898             No         No     NaN      No          No  208021.0
#
#                state      district    Tier T_B_30_status   zone  \
# 7894     Maharashtra         Dhule  Tier 3          B_30   WEST
# 7895   Uttar Pradesh    Rae Bareli  Tier 3          B_30  NORTH
# 7896   Uttar Pradesh       Sambhal  Tier 3          B_30  NORTH
# 7897  Madhya Pradesh   Narsinghpur  Tier 3          B_30   WEST
# 7898   Uttar Pradesh  KANPUR NAGAR  Tier 2          T_30  NORTH
#
#       itr_filed_in_campaign_period_2021  itr_filed_in_campaign_period_2022  \
# 7894                                NaN                                NaN
# 7895                                NaN                                NaN
# 7896                                NaN                                NaN
# 7897                                NaN                                NaN
# 7898                                NaN                                NaN
#
#       itr_filed_in_campaign_period_2023  itr_filed_in_campaign_period_2024  \
# 7894                                3.0                                5.0
# 7895                                4.0                                2.0
# 7896                                NaN                                NaN
# 7897                                NaN                                2.0
# 7898                                NaN                                NaN
#
#                 contest_status              json_mode    _26as_imported_on  \
# 7894  contest_winner_only_2023                    NaN  2024-04-23T09:30:02
# 7895  contest_winner_only_2023  json_prepared_outside  2025-01-06T18:21:29
# 7896                       NaN                    NaN  2025-01-26T09:41:01
# 7897                       NaN  json_prepared_outside  2024-07-28T21:17:53
# 7898                       NaN  json_prepared_outside  2024-09-01T21:50:57
#
#      _26as_import_status ais_status         details_added_by GSTR_Status  \
# 7894      _26as_imported        NaN  income_detail_by_client         NaN
# 7895      _26as_imported        ais     income_detail_by_VLE         NaN
# 7896      _26as_imported        NaN  income_detail_by_client         NaN
# 7897      _26as_imported        ais     income_detail_by_VLE         NaN
# 7898      _26as_imported        ais     income_detail_by_VLE         NaN
#
#      Ops_category1_status         Ops_category2_status Ops_category3_status  \
# 7894                  NaN                  ITR U 23 24                  NaN
# 7895                  NaN                 Lottery case                   p1
# 7896                  NaN  Advance payment For filing                   NaN
# 7897                  NaN            Capital Gain Case                  NaN
# 7898                  NaN            Capital Gain Case                   p0
#
#       team_reamrks_count User_type   Vle_type   Income_band     FY_Year  \
# 7894                 6.0  New_User  Retro_Vle  G).No_Income  FY 2024-25
# 7895                 1.0  New_User  Retro_Vle  G).No_Income  FY 2024-25
# 7896                 1.0  New_User  Retro_Vle  G).No_Income  FY 2024-25
# 7897                 1.0  New_User  Retro_Vle  G).No_Income  FY 2024-25
# 7898                 5.0  New_User    New_Vle  G).No_Income  FY 2024-25
#
#       Days_E_verification  Days_E_verification_done  \
# 7894                  NaN                       NaN
# 7895                  0.0                      36.0
# 7896                  NaN                       NaN
# 7897                  1.0                     198.0
# 7898                  0.0                     160.0
#
#                    E_verification_bucket
# 7894     F)Pending for more than 30 days
# 7895  A) e_verified between 0 to 2 weeks
# 7896     E) Pending between 3 to 4 weeks
# 7897  A) e_verified between 0 to 2 weeks
# 7898  A) e_verified between 0 to 2 weeks

# %%
offline_df.count()
# Out:
# emitra_id                   7899
# itr_id                      7899
# sp_name                     7899
# sso_id                      7899
# sp_transaction_id           7815
#                             ...
# Income_band                 7899
# FY_Year                     7899
# Days_E_verification         2768
# Days_E_verification_done    2768
# E_verification_bucket       7898
# Length: 105, dtype: int64

# %%
list(offline_df.columns)
# Out:
# ['emitra_id',
#  'itr_id',
#  'sp_name',
#  'sso_id',
#  'sp_transaction_id',
#  'csc_id',
#  'merchant_id',
#  'merchant_name',
#  'merchant_email',
#  'merchant_phone',
#  'pi_vle_email',
#  'pi_vle_phone',
#  'merchant_vle_email',
#  'merchant_vle_phone',
#  'Customer_name',
#  'Customer_mobile_no',
#  'customer_email',
#  'pan',
#  'Payment_datetime',
#  'Payment_date',
#  'user_created',
#  'cust_first_filing_date',
#  'cust_last_filing_date',
#  'Merchant_first_filing_date',
#  'merchant_last_filing_date',
#  'merchant_created_on',
#  'LSP_Deatils',
#  'merchant_created_month_year',
#  'transactionid',
#  'transamt',
#  'Gross_revenue',
#  'Net_Revenue',
#  'Net_Revenue_with_gst',
#  'assessment_year',
#  'form_name',
#  'itr_status',
#  'itr_status_remarks',
#  'filing_Status',
#  'ack_no',
#  'itr_e_verified_on',
#  'E_verification_status',
#  'filing_timestamp',
#  'deductor_name_base',
#  'deductor_name',
#  'delegate_status',
#  'Filing_type',
#  'Filing_mode',
#  'Plan_amt_range',
#  'plan',
#  'plan_mrp',
#  'plan_offer',
#  'plan_rate',
#  'plan_mrp_without_discount',
#  'plan_commission',
#  'Age_bucket',
#  'gender',
#  'Latest_Salaried_income',
#  'Latest_Business_income',
#  'Latest_os_income',
#  'Latest_hp_income',
#  'Latest_Business_income_band',
#  'Latest_Salaried_income_band',
#  'Latest_os_income_band',
#  'Latest_hp_income_band',
#  'Latest_capital_gain_band',
#  'Gross_total_income_band',
#  'income_by_form',
#  'total_income_band',
#  'tds_refund_band',
#  'Tax_payable_slabs',
#  'Tax_deducted',
#  'tax_deducted_band',
#  'Form_16_upload',
#  'Tax_liable',
#  'EightyC',
#  'Eightyd',
#  'Eightyccd1b',
#  'pincode',
#  'state',
#  'district',
#  'Tier',
#  'T_B_30_status',
#  'zone',
#  'itr_filed_in_campaign_period_2021',
#  'itr_filed_in_campaign_period_2022',
#  'itr_filed_in_campaign_period_2023',
#  'itr_filed_in_campaign_period_2024',
#  'contest_status',
#  'json_mode',
#  '_26as_imported_on',
#  '_26as_import_status',
#  'ais_status',
#  'details_added_by',
#  'GSTR_Status',
#  'Ops_category1_status',
#  'Ops_category2_status',
#  'Ops_category3_status',
#  'team_reamrks_count',
#  'User_type',
#  'Vle_type',
#  'Income_band',
#  'FY_Year',
#  'Days_E_verification',
#  'Days_E_verification_done',
#  'E_verification_bucket']

# %%
selected_column = ['emitra_id',
 'itr_id',
 'sp_name',
 'sso_id',
 'Payment_datetime',
 'Payment_date',
 'Merchant_first_filing_date',
 'merchant_last_filing_date',
 'merchant_created_on',
 'Gross_revenue',
 'Net_Revenue',
 'Net_Revenue_with_gst',
 'assessment_year',
 'form_name',
 'itr_status',
 'filing_Status',
 'E_verification_status',
 'Filing_type',
 'Filing_mode',
 'Age_bucket',
 'gender',
 'Latest_Business_income_band',
 'Latest_Salaried_income_band',
 'Latest_os_income_band',
 'Latest_hp_income_band',
 'Latest_capital_gain_band',
 'Gross_total_income_band',
 'total_income_band',
 'tds_refund_band',
 'Tax_payable_slabs',
 'tax_deducted_band',
 'state',
 'Tier',
 'zone',
 'contest_status',
 'Ops_category1_status',
 'Ops_category2_status',
 'Ops_category3_status',
 'team_reamrks_count',
 'User_type',
 'Vle_type',
 'Income_band',
 'FY_Year']

# %%
df = offline_df[selected_column]

# %%
df.head(5)
# Out:
#    emitra_id   itr_id sp_name  sso_id     Payment_datetime Payment_date  \
# 0     665705  2059165  sp_csc  929814  2024-06-14T13:11:58   2024-06-14
# 1     646264  2030728  sp_csc  387502  2024-05-23T09:29:44   2024-05-23
# 2     707061  2144797  sp_csc  138501  2024-07-12T08:27:26   2024-07-12
# 3     691888  2109081  sp_csc  225636  2024-07-02T17:05:35   2024-07-02
# 4     730799  2197259  sp_csc   87234  2024-07-22T14:11:41   2024-07-22
#
#   Merchant_first_filing_date merchant_last_filing_date merchant_created_on  \
# 0                 2024-06-14                2024-06-14          2024-05-08
# 1                 2022-07-23                2024-07-20          2021-10-09
# 2                 2021-08-19                2024-07-23          2020-07-29
# 3                 2024-07-02                2024-07-02          2021-05-30
# 4                 2019-08-07                2024-07-22          2019-07-29
#
#    Gross_revenue  Net_Revenue  Net_Revenue_with_gst  assessment_year  \
# 0    1500.000000   750.000000                 885.0             2024
# 1     338.135593   169.067797                 199.5             2024
# 2     338.135593   169.067797                 199.5             2024
# 3     544.067797   272.033898                 321.0             2024
# 4     544.067797   272.033898                 321.0             2024
#
#   form_name itr_status filing_Status E_verification_status      Filing_type  \
# 0     ITR-4   imported      imported          Not_verified  customer_filing
# 1     ITR-2     closed        closed          Not_verified  customer_filing
# 2     ITR-2       open          open          Not_verified  customer_filing
# 3     ITR-4   imported      imported          Not_verified  customer_filing
# 4     ITR-4   imported      imported          Not_verified       VLE Filing
#
#   Filing_mode         Age_bucket gender Latest_Business_income_band  \
# 0         NaN  between 25 and 40    NaN                         a)0
# 1         NaN  between 41 and 60      M                         a)0
# 2         NaN  between 41 and 60      M                         a)0
# 3         NaN  between 25 and 40    NaN                         a)0
# 4         NaN  between 41 and 60    NaN                         a)0
#
#   Latest_Salaried_income_band Latest_os_income_band Latest_hp_income_band  \
# 0                         a)0                   a)0                   a)0
# 1                         a)0                   a)0                   a)0
# 2                         a)0                   a)0                   a)0
# 3                         a)0                   a)0                   a)0
# 4                         a)0                   a)0                   a)0
#
#   Latest_capital_gain_band Gross_total_income_band total_income_band  \
# 0                      a)0                     a)0               a)0
# 1                      a)0                     a)0               a)0
# 2                      a)0                     a)0               a)0
# 3                      a)0                     a)0               a)0
# 4                      a)0                     a)0               a)0
#
#   tds_refund_band Tax_payable_slabs tax_deducted_band        state    Tier  \
# 0           a).₹0            No_tax             a).₹0        Delhi  Tier 3
# 1           a).₹0            No_tax             a).₹0    Jharkhand  Tier 3
# 2           a).₹0            No_tax             a).₹0        Assam  Tier 3
# 3           a).₹0            No_tax             a).₹0  Maharashtra  Tier 3
# 4           a).₹0            No_tax             a).₹0    Jharkhand  Tier 3
#
#     zone            contest_status Ops_category1_status  \
# 0  NORTH                       NaN                  NaN
# 1   EAST  contest_winner_only_2023         TO BE CLOSED
# 2   EAST  contest_winner_only_2023                  NaN
# 3   WEST                       NaN                  NaN
# 4   EAST  contest_winner_only_2023                  NaN
#
#       Ops_category2_status Ops_category3_status  team_reamrks_count  \
# 0          wrong password                   NaN                 6.0
# 1             TO BE CLOSED                  NaN                 5.0
# 2  194LA Documents pending                   p1                 7.0
# 3        Details Pending                    NaN                 7.0
# 4                     hold                  NaN                 3.0
#
#     User_type   Vle_type   Income_band     FY_Year
# 0  Retro_User    New_Vle  G).No_Income  FY 2024-25
# 1    New_User  Retro_Vle  G).No_Income  FY 2024-25
# 2    New_User  Retro_Vle  G).No_Income  FY 2024-25
# 3    New_User    New_Vle  G).No_Income  FY 2024-25
# 4  Retro_User  Retro_Vle  G).No_Income  FY 2024-25

# %%
list(df.columns)
# Out:
# ['emitra_id',
#  'itr_id',
#  'sp_name',
#  'sso_id',
#  'Payment_datetime',
#  'Payment_date',
#  'Merchant_first_filing_date',
#  'merchant_last_filing_date',
#  'merchant_created_on',
#  'Gross_revenue',
#  'Net_Revenue',
#  'Net_Revenue_with_gst',
#  'assessment_year',
#  'form_name',
#  'itr_status',
#  'filing_Status',
#  'E_verification_status',
#  'Filing_type',
#  'Filing_mode',
#  'Age_bucket',
#  'gender',
#  'Latest_Business_income_band',
#  'Latest_Salaried_income_band',
#  'Latest_os_income_band',
#  'Latest_hp_income_band',
#  'Latest_capital_gain_band',
#  'Gross_total_income_band',
#  'total_income_band',
#  'tds_refund_band',
#  'Tax_payable_slabs',
#  'tax_deducted_band',
#  'state',
#  'Tier',
#  'zone',
#  'contest_status',
#  'Ops_category1_status',
#  'Ops_category2_status',
#  'Ops_category3_status',
#  'team_reamrks_count',
#  'User_type',
#  'Vle_type',
#  'Income_band',
#  'FY_Year']

# %% [markdown]
# """
# WILL HANDLE NULL VALUES WHILE WORKING AS I DONT WANT TO REMOVE OR REPLACE NULL VALUES NOW
# """

# %%
df["sp_name"].count()
# Out:
# 7899

# %%
df["sp_name"].unique()
# Out:
# array(['sp_csc', 'emitra', 'quicksun', 'vayamtech'], dtype=object)

# %%
df.groupby("sp_name").count()
# Out:
#            emitra_id  itr_id  sso_id  Payment_datetime  Payment_date  \
# sp_name
# emitra             1       1       1                 1             1
# quicksun          23      23      23                23            23
# sp_csc          7870    7870    7870              7870          7870
# vayamtech          5       5       5                 5             5
#
#            Merchant_first_filing_date  merchant_last_filing_date  \
# sp_name
# emitra                              1                          1
# quicksun                           23                         23
# sp_csc                           7870                       7870
# vayamtech                           5                          5
#
#            merchant_created_on  Gross_revenue  Net_Revenue  \
# sp_name
# emitra                       1              0            0
# quicksun                    23             23           23
# sp_csc                    7870           7870         7870
# vayamtech                    5              5            5
#
#            Net_Revenue_with_gst  assessment_year  form_name  itr_status  \
# sp_name
# emitra                        0                1          1           1
# quicksun                     23               23         23          23
# sp_csc                     7870             7870       7870        7870
# vayamtech                     5                5          5           5
#
#            filing_Status  E_verification_status  Filing_type  Filing_mode  \
# sp_name
# emitra                 1                      1            1            1
# quicksun              23                     23           23           16
# sp_csc              7870                   7870         7870         4374
# vayamtech              5                      5            5            2
#
#            Age_bucket  gender  Latest_Business_income_band  \
# sp_name
# emitra              1       0                            1
# quicksun           23       5                           23
# sp_csc           7869    1892                         7870
# vayamtech           5       1                            5
#
#            Latest_Salaried_income_band  Latest_os_income_band  \
# sp_name
# emitra                               1                      1
# quicksun                            23                     23
# sp_csc                            7870                   7870
# vayamtech                            5                      5
#
#            Latest_hp_income_band  Latest_capital_gain_band  \
# sp_name
# emitra                         1                         1
# quicksun                      23                        23
# sp_csc                      7870                      7870
# vayamtech                      5                         5
#
#            Gross_total_income_band  total_income_band  tds_refund_band  \
# sp_name
# emitra                           1                  1                1
# quicksun                        23                 23               23
# sp_csc                        7870               7870             7870
# vayamtech                        5                  5                5
#
#            Tax_payable_slabs  tax_deducted_band  state  Tier  zone  \
# sp_name
# emitra                     1                  1      1     1     1
# quicksun                  23                 23     23    23    23
# sp_csc                  7870               7870   7866  7783  7783
# vayamtech                  5                  5      5     5     5
#
#            contest_status  Ops_category1_status  Ops_category2_status  \
# sp_name
# emitra                  0                     0                     1
# quicksun                0                     1                    21
# sp_csc               2097                  1022                  7114
# vayamtech               0                     2                     3
#
#            Ops_category3_status  team_reamrks_count  User_type  Vle_type  \
# sp_name
# emitra                        0                   1          1         1
# quicksun                      6                  23         23        23
# sp_csc                     1340                7862       7870      7870
# vayamtech                     1                   5          5         5
#
#            Income_band  FY_Year
# sp_name
# emitra               1        1
# quicksun            23       23
# sp_csc            7870     7870
# vayamtech            5        5

# %%
df.groupby("sp_name")['emitra_id'].count()
# Out:
# sp_name
# emitra          1
# quicksun       23
# sp_csc       7870
# vayamtech       5
# Name: emitra_id, dtype: int64

# %%
partner_wise_filing_count = df.groupby("sp_name")['emitra_id'].count().reset_index(name='filing_count')
partner_wise_filing_count
# Out:
#      sp_name  filing_count
# 0     emitra             1
# 1   quicksun            23
# 2     sp_csc          7870
# 3  vayamtech             5

# %%
fig = px.bar(
    partner_wise_filing_count,
    x = 'sp_name',
    y = 'filing_count',
    title = 'partner wise filing',
    text_auto = True ,
    color_continuous_scale='blues'
    )
fig.update_traces(
    textposition="outside",
    marker_line_color = 'black',
    marker_line_width=1. ,
) 
fig.update_layout(yaxis=dict(range=[0, partner_wise_filing_count["filing_count"].max() * 1.2]))
fig.show()
